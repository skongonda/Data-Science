# %%
import pandas as pd
import requests

from warnings import filterwarnings
filterwarnings('ignore')

# %%
requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=efc94a982d370d6931f6693ce6fffd83&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=efc94a982d370d6931f6693ce6fffd83&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/avedvodAZUcwqevBfm8p4G2NziQ.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 251.609,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.706,
#    'vote_count': 26653},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/avedvodAZUcwqevBfm8p4G2NziQ.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 251.609,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.706,
#   'vote_count': 26653},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
# This is only page 1 information.

pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#          id                                          title  \
# 0       278                       The Shawshank Redemption
# 1       238                                  The Godfather
# 2       240                          The Godfather Part II
# 3       424                               Schindler's List
# 4       389                                   12 Angry Men
# 5       129                                  Spirited Away
# 6     19404                    Dilwale Dulhania Le Jayenge
# 7       155                                The Dark Knight
# 8    496243                                       Parasite
# 9       497                                 The Green Mile
# 10   372058                                     Your Name.
# 11      680                                   Pulp Fiction
# 12      122  The Lord of the Rings: The Return of the King
# 13       13                                   Forrest Gump
# 14  1084736                      The Count of Monte-Cristo
# ...

# %%
new_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
new_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     251.609
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     260.391
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      97.287
# 3  The true story of how businessman Oskar Schind...   1993-12-15     188.831
# 4  The defense and the prosecution have rested an...   1957-04-10      73.518
#
#    vote_average  vote_count
# 0         8.706       26653
# 1         8.690       20217
# 2         8.575       12201
# 3         8.565       15605
# 4         8.543        8448

# %%
new_df.tail()
# Out:
#         id                           title  \
# 15     769                      GoodFellas
# 16     346                   Seven Samurai
# 17     429  The Good, the Bad and the Ugly
# 18  667257               Impossible Things
# 19   12477          Grave of the Fireflies
#
#                                              overview release_date  \
# 15  The true story of Henry Hill, a half-Irish, ha...   1990-09-12
# 16  A samurai answers a village's request for prot...   1954-04-26
# 17  While the Civil War rages on between the Union...   1966-12-22
# 18  After the death of her abusive husband, Matild...   2021-06-17
# 19  In the final months of World War II, 14-year-o...   1988-04-16
#
#     popularity  vote_average  vote_count
# 15      77.189         8.463       12628
# 16      64.465         8.462        3583
# 17     146.986         8.462        8434
# 18      21.609         8.500         380
# 19       0.060         8.457        5362

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,480):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df,temp_df], ignore_index=True)

# %%
df
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ...     ...                         ...
# 9561  12142           Alone in the Dark
# 9562  13805              Disaster Movie
# 9563  11059           House of the Dead
# 9564  14164        Dragonball Evolution
# 9565  40016  Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...

# %%
df.shape
# Out:
# (9566, 7)

# %%
df.to_csv('E:/Python Programs/Fetching Data From an API_movies.csv')
